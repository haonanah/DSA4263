# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/Fraudulent_online_shops_dataset.csv')

# %%
df.head()
# Out:
#                         Online shop URL       Label  Domain length  \
# 0      https://www.allaccessorybest.com  fraudulent             24
# 1            https://www.b-watches.shop  fraudulent             18
# 2  https://www.waeschenamen-windrath.de  legitimate             28
# 3                 https://vendoprint.se  legitimate             13
# 4           https://www.newbikeland.com  fraudulent             19
#
#    Top domain length  Presence of prefix 'www'   Number  of digits  \
# 0                  3                          1                  0
# 1                  4                          1                  0
# 2                  2                          1                  0
# 3                  2                          0                  0
# 4                  3                          1                  0
#
#    Number  of letters  Number  of dots (.)  Number  of hyphens (-)  \
# 0                  27                    2                       0
# ...

# %%
df.describe()
# Out:
#        Domain length  Top domain length  Presence of prefix 'www'  \
# count    1140.000000        1140.000000               1140.000000
# mean       18.341228           2.851754                  0.665789
# std         4.512033           0.741322                  0.471921
# min         7.000000           2.000000                  0.000000
# 25%        15.000000           2.000000                  0.000000
# 50%        19.000000           3.000000                  1.000000
# 75%        21.000000           3.000000                  1.000000
# max        38.000000          13.000000                  1.000000
#
#        Number of digits  Number of letters  Number of dots (.)  \
# count       1140.000000        1140.000000         1140.000000
# mean           0.070175          21.654386            1.708772
# std            0.395748           4.307723            0.495203
# min            0.000000          11.000000            1.000000
# ...

# %% [markdown]
# ## Handling of NA values

# %%
df.isna().any()
# Out:
# Online shop URL                                  False
# Label                                            False
# Domain length                                    False
# Top domain length                                False
# Presence of prefix 'www'                         False
# Number  of digits                                False
# Number  of letters                               False
# Number  of dots (.)                              False
# Number  of hyphens (-)                           False
# Presence of credit card payment                  False
# Presence of money back payment                   False
# Presence of cash on delivery payment             False
# Presence of crypto currency                      False
# Presence of free contact emails                  False
# Presence of logo URL                             False
# SSL certificate issuer                           False
# SSL certificate expire date                      False
# ...

# %% [markdown]
# ### Domain Registration date NA values

# %%
# only 4 websites do not have a DR date (all are fraudulent)
df[df['Domain registration date'].isna()]
# Out:
#                  Online shop URL       Label  Domain length  \
# 229            https://get-rc.to  fraudulent              9
# 263         https://axfritz.shop  fraudulent             12
# 1138     https://www.arlton.shop  fraudulent             15
# 1139  https://www.ghingwala.shop  fraudulent             18
#
#       Top domain length  Presence of prefix 'www'   Number  of digits  \
# 229                   2                          0                  0
# 263                   4                          0                  0
# 1138                  4                          1                  0
# 1139                  4                          1                  0
#
#       Number  of letters  Number  of dots (.)  Number  of hyphens (-)  \
# 229                   12                    1                       1
# 263                   16                    1                       0
# 1138                  18                    2                       0
# ...

# %% [markdown]
# ### TrustPilot score NA values

# %%
df_tp_na = df[df['TrustPilot score'].isna()]['Label']

# %%
# all 560 records with NaN TrustPilot Score are fraudulent
(df_tp_na == 'fraudulent').all()
# Out:
# True

# %%
# replace NaN with -1 for those with no score
df['TrustPilot score'] = df['TrustPilot score'].fillna(-1)

# %%
df[df['TrustPilot score'].isna()]
# Out:
# Empty DataFrame
# Columns: [Online shop URL, Label, Domain length, Top domain length, Presence of prefix 'www' , Number  of digits, Number  of letters, Number  of dots (.), Number  of hyphens (-), Presence of credit card payment, Presence of money back payment, Presence of cash on delivery payment, Presence of crypto currency, Presence of free contact emails, Presence of logo URL, SSL certificate issuer, SSL certificate expire date, Issuer organization, SSL certificate issuer organization list item, Indication of young domain , Domain registration date, Presence of TrustPilot reviews, TrustPilot score, Presence of SiteJabber reviews, Presence in the standard Tranco list, Tranco List rank]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# ## Data Cleaning

# %%
# Make sure column names have only one space between each word
df.columns = df.columns.str.replace(r'\s+', ' ', regex=True).str.strip()

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Domain Features

# %%
plt.figure(figsize=(10,6))
data['Domain length'].plot(kind='hist', bins=30, edgecolor='black')

# Labels and title
plt.xlabel('Domain Length')
plt.ylabel('Frequency')
plt.title('Distribution of Domain Lengths')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Label', y='Domain length', data=df, palette='coolwarm')
plt.title('Domain Length Comparison: Fraudulent vs Legitimate E-Shops')
plt.show()
# Out:
# C:\Users\teomi\AppData\Local\Temp\ipykernel_3688\3426729639.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Label', y='Domain length', data=df, palette='coolwarm')

# %%
for col in ['Domain length', 'Number of digits', 'Number of letters']:
    sns.kdeplot(df[col], fill=True, label=col)
plt.legend()
plt.title('KDE Plot of Domain Features')
plt.show()

# %%
df_da = df[['Label', 'Indication of young domain']]
df_da['Domain age classification'] = df_da ['Indication of young domain'].map({0: 'old', 1: 'young', 2: 'hidden'})
sns.countplot(x='Domain age classification', hue='Label', data=df_da, palette='coolwarm', order = ['young', 'old', 'hidden'])
plt.title('Domain Age of Fraudulent vs Legitimate E-Shops')
plt.show()
# Out:
# C:\Users\teomi\AppData\Local\Temp\ipykernel_3688\3987470325.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_da['Domain age classification'] = df_da ['Indication of young domain'].map({0: 'old', 1: 'young', 2: 'hidden'})

# %% [markdown]
# ### Payment Features

# %%
payment_methods = ['Presence of credit card payment', 'Presence of money back payment', 
                   'Presence of cash on delivery payment', 'Presence of crypto currency']

df_melted = df.melt(id_vars=['Label'], value_vars=payment_methods, var_name="Payment Method", value_name="Presence")
graph = sns.catplot(x="Payment Method", hue="Label", col="Presence", data=df_melted, kind="count", height=5, aspect=1.5)
for ax in graph.axes.flatten():
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
plt.show()
# Out:
# C:\Users\teomi\AppData\Local\Temp\ipykernel_3688\1165446664.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# C:\Users\teomi\AppData\Local\Temp\ipykernel_3688\1165446664.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# %% [markdown]
# ### TrustPilot Score

# %%
df_tps = df[['Label', 'TrustPilot score']]
bins = [-2, 0, 1, 2, 3, 4, 5]
labels = ['No reviews', '0-1', '1.1-2', '2.1-3', '3.1-4', '4.1-5']
df_tps['TrustPilot score'] = pd.cut(df_tps['TrustPilot score'], bins=bins, labels=labels)
sns.countplot(x='TrustPilot score', hue='Label', data=df_tps, palette='coolwarm')
plt.title('TrustPilot scores of Fraudulent vs Legitimate E-Shops')
plt.show()
# Out:
# C:\Users\teomi\AppData\Local\Temp\ipykernel_3688\2859389593.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tps['TrustPilot score'] = pd.cut(df_tps['TrustPilot score'], bins=bins, labels=labels)

# %% [markdown]
# ### Tranco List

# %%
df['Tranco List rank'].value_counts().reset_index()
# Out:
#     Tranco List rank  count
# 0                 -1   1122
# 1             100803      1
# 2             964101      1
# 3             750712      1
# 4             346606      1
# 5             918108      1
# 6             796877      1
# 7             797093      1
# 8             875089      1
# 9             538286      1
# 10             90036      1
# 11            682488      1
# 12            802653      1
# 13            825217      1
# 14            459343      1
# 15             35556      1
# 16            804620      1
# 17            802243      1
# 18            481570      1
